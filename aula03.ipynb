# %% [markdown]
# <a href="https://colab.research.google.com/github/santesophia20-star/pa/blob/main/aula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# aula de programação e algoritimo
# * calcular a área de uma sala
# # entrada
# medir o comprimento da sala
# medir a lagura da sala
# # processamento
# fazer a multiplicação
# # saida
# mostrar o resultado

# %%
# entrada
comprimento= 7 # metros
largura = 4 # metros

# %%
# processamento
area= comprimento * largura

# %%
print (f"área total da sala é:{area} metros quadrados")
# Out:
# área total da sala é:28 metros quadrados

# %%
# entrada
lado = 2
# processamento
resultado = lado * lado
# saida
print (f" o resultado do quadrado é:  {resultado}" )
# Out:
#  o resultado do quadrado é:  4

# %% [markdown]
# ativdade: *escrever um algoritomo e depois o programa que recebe um numero e calcula o dobro desse numero

# %% [markdown]
# # entrada
# ler o numero
# # processamento
# multiplicar vezes  2
# # saida
# mostrar o dobro do numero

# %%
# entrada
numero = 3
# processamento
dobro = numero * 2
# saida
print (f"o dobro do numero digitado é: {dobro} ")
# Out:
# o dobro do numero digitado é: 6

# %% [markdown]
# operadores aritimeticos
# soma = +
#
# subtração = -
#
# multiplicação = *
#
# divisão = /

# %% [markdown]
# escrever um algoritimo e o programa que receba 4 notas do aluno e calcula a media dessas notas e mostrar a media

# %% [markdown]
# # entrada
# calcular a media de notas de um aluno
# # processamento
# somar todas as notas e dividir pelo numero de notas
# #saida
# resultado

# %%
# entrada
notas = []

quantidade = int(input("Digite o número de notas: "))

for i in range(quantidade):
    nota = float(input(f"Digite a nota {i+1}: "))
    notas.append(nota)

# processamento
soma = sum(notas)
media = soma / quantidade

# saída
print("A média do aluno é:", media)
# Out:
# Digite o número de notas: 2
# Digite a nota 1: 10
# Digite a nota 2: 3
# A média do aluno é: 6.5
