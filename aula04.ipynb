# %% [markdown]
# <a href="https://colab.research.google.com/github/santesophia20-star/pa/blob/main/aula04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Escrever um programa que faça cálculos aritiméticos
#Entrada

a=int (input("digite o primeiro número"))
b=int(input("digite o segundo número"))

#processamento

soma = a+b
subtracao = a-b
multiplicacao = a * b
divisao = a//b
div_int = a //b #Usar barras duplas "//" para divisões inteira
resto = a % b # o simbolo de % é igual ao resto da divisão

#Saída

print("---------------CALCULADORA SIMPLES---------------")
print("")
print ("---------------soma---------------")
print("")
print(f"o resultado da soma{a} mais {b} é igual: {soma}")
print("")
print("---------------subtração---------------")
print("")
print(f"o resultado da subtração{a} menos {b} é igual: {subtracao}")
print ("")
print("---------------multiplicação---------------")
print(f"o resultado da multiplicação{a} vezes {b} é igual: {multiplicacao}")
print("")
print("---------------divisão---------------")
print("")
print ( f"o resultado da divisão de {a} dividido {b} é igual: {divisao}")
print  ("---------------divisão inteira---------------")
print("")
print(f"o resultado da divisão inteira de {a} dividido por {b} é igual: {div_int}")
print("")
print("---------------resto da divisão---------------")
print("")
print(f"o resultado do resto da divisão de {a} dividido por {b} é igual: {resto}")
# Out:
# digite o primeiro número25
# digite o segundo número12
# ---------------CALCULADORA SIMPLES---------------
#
# ---------------soma---------------
#
# o resultado da soma25 mais 12 é igual: 37
#
# ---------------subtração---------------
#
# o resultado da subtração25 menos 12 é igual: 13
#
# ---------------multiplicação---------------
# o resultado da multiplicação25 vezes 12 é igual: 300
#
# ---------------divisão---------------
#
# o resultado da divisão de 25 dividido 12 é igual: 2
# ---------------divisão inteira---------------
#
# o resultado da divisão inteira de 25 dividido por 12 é igual: 2
#
# ---------------resto da divisão---------------
#
# o resultado do resto da divisão de 25 dividido por 12 é igual: 1

# %% [markdown]
# escrever um programa que recebe a temperetura em graus celsius  e converte para Fahrenheit
# #entrada graus celsius
#
# #procesamento
# F = C x 9/5) +32
#
#  #saida
#  mostrar graus em fahrenheit
#
#  para casa
